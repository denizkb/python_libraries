# %%
import pandas as pd

df = pd.read_csv("avocado.csv")

df["Date"] = pd.to_datetime( df["Date"])

albany_df = df[ df["region"] == 'Albany' ]

albany_df.set_index('Date', inplace = True)

albany_df["AveragePrice"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
albany_df["AveragePrice"].rolling(25).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
albany_df.sort_index(inplace = True)

albany_df["AveragePrice"].rolling(25).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
albany_df["price25ma"] = albany_df["AveragePrice"].rolling(25).mean()
# Out:
# <ipython-input-10-c1f362f23412>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   albany_df["price25ma"] = albany_df["AveragePrice"].rolling(25).mean()

# %%
albany_df.head(3)
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046      4225    4770  \
# Date
# 2015-01-04          51          1.22      40873.28  2819.50  28287.42   49.90
# 2015-01-04          51          1.79       1373.95    57.42    153.88    0.00
# 2015-01-11          50          1.24      41195.08  1002.85  31640.34  127.12
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# 2015-01-04     9716.46     9186.93      529.53          0.0  conventional
# 2015-01-04     1162.65     1162.65        0.00          0.0       organic
# 2015-01-11     8424.77     8036.04      388.73          0.0  conventional
#
#             year  region  price25ma
# Date
# 2015-01-04  2015  Albany        NaN
# 2015-01-04  2015  Albany        NaN
# 2015-01-11  2015  Albany        NaN

# %%
albany_df.tail(3)
# Out:
#             Unnamed: 0  AveragePrice  Total Volume      4046       4225  \
# Date
# 2018-03-18           1          1.35     105304.65  13234.86   61037.58
# 2018-03-25           0          1.57     149396.50  16361.69  109045.03
# 2018-03-25           0          1.71       2321.82     42.95     272.41
#
#              4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2018-03-18  55.00    30977.21    26755.90     3721.31        500.0
# 2018-03-25  65.45    23924.33    19273.80     4270.53        380.0
# 2018-03-25   0.00     2006.46     1996.46       10.00          0.0
#
#                     type  year  region  price25ma
# Date
# 2018-03-18  conventional  2018  Albany     1.4276
# 2018-03-25  conventional  2018  Albany     1.4272
# 2018-03-25       organic  2018  Albany     1.4368

# %%
#drop any columns has na value
albany_df.dropna().head(3)
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046      4225   4770  \
# Date
# 2015-03-29          39          1.93       1082.44    24.75    173.26   0.00
# 2015-03-29          39          1.02      67799.08  1402.28  58623.22  89.50
# 2015-04-05          38          1.16      47362.13   961.77  35577.66  93.76
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# 2015-03-29      884.43      884.43        0.00         0.00       organic
# 2015-03-29     7684.08     7208.49      475.59         0.00  conventional
# 2015-04-05    10728.94     9869.16      755.61       104.17  conventional
#
#             year  region  price25ma
# Date
# 2015-03-29  2015  Albany     1.4660
# 2015-03-29  2015  Albany     1.4580
# 2015-04-05  2015  Albany     1.4328

# %%
albany_df = df.copy()[df["region"] == 'Albany']
albany_df.set_index('Date', inplace = True)
albany_df.sort_index(inplace = True)
albany_df["price25ma"] = albany_df["AveragePrice"].rolling(25).mean()

# %%
df.values
# Out:
# array([[0, Timestamp('2015-12-27 00:00:00'), 1.33, ..., 'conventional',
#         2015, 'Albany'],
#        [1, Timestamp('2015-12-20 00:00:00'), 1.35, ..., 'conventional',
#         2015, 'Albany'],
#        [2, Timestamp('2015-12-13 00:00:00'), 0.93, ..., 'conventional',
#         2015, 'Albany'],
#        ...,
#        [9, Timestamp('2018-01-21 00:00:00'), 1.87, ..., 'organic', 2018,
#         'WestTexNewMexico'],
#        [10, Timestamp('2018-01-14 00:00:00'), 1.93, ..., 'organic', 2018,
#         'WestTexNewMexico'],
#        [11, Timestamp('2018-01-07 00:00:00'), 1.62, ..., 'organic', 2018,
#         'WestTexNewMexico']], dtype=object)

# %%
df['region'].values
# Out:
# array(['Albany', 'Albany', 'Albany', ..., 'WestTexNewMexico',
#        'WestTexNewMexico', 'WestTexNewMexico'], dtype=object)

# %%
# long list df['region'].values.tolist()
#to have unique item convert to set
set(df['region'].values.tolist())
# Out:
# {'Albany',
#  'Atlanta',
#  'BaltimoreWashington',
#  'Boise',
#  'Boston',
#  'BuffaloRochester',
#  'California',
#  'Charlotte',
#  'Chicago',
#  'CincinnatiDayton',
#  'Columbus',
#  'DallasFtWorth',
#  'Denver',
#  'Detroit',
#  'GrandRapids',
#  'GreatLakes',
#  'HarrisburgScranton',
#  'HartfordSpringfield',
#  'Houston',
#  'Indianapolis',
#  'Jacksonville',
#  'LasVegas',
#  'LosAngeles',
#  'Louisville',
#  'MiamiFtLauderdale',
#  'Midsouth',
#  'Nashville',
#  'NewOrleansMobile',
#  'NewYork',
#  'Northeast',
#  'NorthernNewEngland',
#  'Orlando',
#  'Philadelphia',
#  'PhoenixTucson',
#  'Pittsburgh',
#  'Plains',
#  'Portland',
#  'RaleighGreensboro',
#  'RichmondNorfolk',
#  'Roanoke',
#  'Sacramento',
#  'SanDiego',
#  'SanFrancisco',
#  'Seattle',
#  'SouthCarolina',
#  'SouthCentral',
#  'Southeast',
#  'Spokane',
#  'StLouis',
#  'Syracuse',
#  'Tampa',
#  'TotalUS',
#  'West',
#  'WestTexNewMexico'}

# %%
# convert the set to the list, we can iterate this list
list(set(df['region'].values.tolist()))
# Out:
# ['SouthCentral',
#  'Chicago',
#  'GreatLakes',
#  'Indianapolis',
#  'CincinnatiDayton',
#  'Pittsburgh',
#  'SanDiego',
#  'DallasFtWorth',
#  'West',
#  'SanFrancisco',
#  'Nashville',
#  'BaltimoreWashington',
#  'California',
#  'NorthernNewEngland',
#  'Midsouth',
#  'Southeast',
#  'Detroit',
#  'BuffaloRochester',
#  'Northeast',
#  'HarrisburgScranton',
#  'RaleighGreensboro',
#  'Sacramento',
#  'Syracuse',
#  'Atlanta',
#  'GrandRapids',
#  'Boise',
#  'StLouis',
#  'Louisville',
#  'HartfordSpringfield',
#  'Boston',
#  'Plains',
#  'LasVegas',
#  'Roanoke',
#  'Denver',
#  'Orlando',
#  'Seattle',
#  'Albany',
#  'SouthCarolina',
#  'Portland',
#  'TotalUS',
#  'NewYork',
#  'Columbus',
#  'PhoenixTucson',
#  'RichmondNorfolk',
#  'Philadelphia',
#  'Houston',
#  'Jacksonville',
#  'LosAngeles',
#  'Spokane',
#  'MiamiFtLauderdale',
#  'Tampa',
#  'NewOrleansMobile',
#  'Charlotte',
#  'WestTexNewMexico']

# %%
df['region'].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
graph_df = pd.DataFrame()

for region in df['region'].unique()[:3]:
    print(region)
    region_df = df.copy([df['region'] == region])
    region_df.set_index('Date', inplace = True)
    region_df.sort_index(inplace = True)
    region_df[f'{region}_price25ma'] = region_df["AveragePrice"].rolling(25).mean()
    
    if graph_df.empty:
        graph_df = region_df[[f'{region}_price25ma']] # we added two brackets, because it is now series, we want to have data frame so we can add columns.
    
    else:
        graph_df = graph_df.join(region_df[f'{region}_price25ma'])

# %%
#dates are multiple for each type. thats why it takes too long.
df['type'].unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %%
import pandas as pd

df = pd.read_csv("avocado.csv")

df = df.copy()[df['type'] == 'organic']

df["Date"] = pd.to_datetime( df["Date"])

df.sort_values(by="Date", ascending = True, inplace = True)

graph_df = pd.DataFrame()

for region in df['region'].unique()[:3]:
    print(region)
    region_df = df.copy([df['region'] == region])
    region_df.set_index('Date', inplace = True)
    region_df.sort_index(inplace = True)
    region_df[f'{region}_price25ma'] = region_df["AveragePrice"].rolling(25).mean()
    
    if graph_df.empty:
        graph_df = region_df[[f'{region}_price25ma']] # we added two brackets, because it is now series, we want to have data frame so we can add columns.
    
    else:
        graph_df = graph_df.join(region_df[f'{region}_price25ma'])
# Out:
# California
# LasVegas
# PhoenixTucson

# %%
graph_df.tail()
# Out:
#             California_price25ma  LasVegas_price25ma  PhoenixTucson_price25ma
# Date
# 2018-03-25                1.5584              1.5584                   1.5604
# 2018-03-25                1.5584              1.5584                   1.5556
# 2018-03-25                1.5584              1.5584                   1.5520
# 2018-03-25                1.5584              1.5584                   1.5576
# 2018-03-25                1.5584              1.5584                   1.5584

# %%
graph_df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
graph_df.dropna().plot(figsize=(8,5), legend = False)
# Out:
# <AxesSubplot:xlabel='Date'>
